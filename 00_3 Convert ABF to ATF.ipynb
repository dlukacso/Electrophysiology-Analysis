# %%
from Modules import convert_abf

# %%
# %%time

reference_file = 'ASCL4 ephys list.xlsx'

convert_abf.convert_files(reference_file)
# Out:
# WARNING:pyabf.abf:fileGUID isn't truly unique (fileUUID is)
# WARNING:pyabf.abf:fileGUID isn't truly unique (fileUUID is)
# All 144 cells had all abf files
# All 144 cells had no problems with their channels
# WARNING:pyabf.abf:fileGUID isn't truly unique (fileUUID is)
# WARNING:pyabf.abf:fileGUID isn't truly unique (fileUUID is)
# WARNING:pyabf.abf:fileGUID isn't truly unique (fileUUID is)
# WARNING:pyabf.abf:fileGUID isn't truly unique (fileUUID is)
# WARNING:pyabf.abf:fileGUID isn't truly unique (fileUUID is)
# WARNING:pyabf.abf:fileGUID isn't truly unique (fileUUID is)
# WARNING:pyabf.abf:fileGUID isn't truly unique (fileUUID is)
# WARNING:pyabf.abf:fileGUID isn't truly unique (fileUUID is)
# WARNING:pyabf.abf:fileGUID isn't truly unique (fileUUID is)
# WARNING:pyabf.abf:fileGUID isn't truly unique (fileUUID is)
# WARNING:pyabf.abf:fileGUID isn't truly unique (fileUUID is)
# WARNING:pyabf.abf:fileGUID isn't truly unique (fileUUID is)
# ...
