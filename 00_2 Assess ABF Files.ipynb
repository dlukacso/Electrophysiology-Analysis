# %%
from Modules import assess_cells

# %% [markdown]
# ### Use This To Get ABF Headers

# %%
# %%time

reference_file = 'ASCL4 ephys list.xlsx'

assess_cells.save_abf_headers(reference_file)
# Out:
# WARNING:pyabf.abf:fileGUID isn't truly unique (fileUUID is)
# WARNING:pyabf.abf:fileGUID isn't truly unique (fileUUID is)
# WARNING:pyabf.abf:fileGUID isn't truly unique (fileUUID is)
# WARNING:pyabf.abf:fileGUID isn't truly unique (fileUUID is)
# WARNING:pyabf.abf:fileGUID isn't truly unique (fileUUID is)
# All 144 cells had all abf files
# WARNING:pyabf.abf:fileGUID isn't truly unique (fileUUID is)
# WARNING:pyabf.abf:fileGUID isn't truly unique (fileUUID is)
# WARNING:pyabf.abf:fileGUID isn't truly unique (fileUUID is)
# WARNING:pyabf.abf:fileGUID isn't truly unique (fileUUID is)
# WARNING:pyabf.abf:fileGUID isn't truly unique (fileUUID is)
# WARNING:pyabf.abf:fileGUID isn't truly unique (fileUUID is)
# WARNING:pyabf.abf:fileGUID isn't truly unique (fileUUID is)
# WARNING:pyabf.abf:fileGUID isn't truly unique (fileUUID is)
# WARNING:pyabf.abf:fileGUID isn't truly unique (fileUUID is)
# WARNING:pyabf.abf:fileGUID isn't truly unique (fileUUID is)
# ...

# %% [markdown]
# ### Use This To Plot Out ABF File Traces

# %%
# %%time

dataset = 'ASCL4 ephys'
reference_file = 'ASCL4 ephys list.xlsx'

assess_cells.plot_abf_data(dataset, reference_file)
# Out:
# WARNING:pyabf.abf:fileGUID isn't truly unique (fileUUID is)
# WARNING:pyabf.abf:fileGUID isn't truly unique (fileUUID is)
# All 144 cells had all abf files
# WARNING:pyabf.abf:fileGUID isn't truly unique (fileUUID is)
# WARNING:pyabf.abf:fileGUID isn't truly unique (fileUUID is)
# WARNING:pyabf.abf:fileGUID isn't truly unique (fileUUID is)
# WARNING:pyabf.abf:fileGUID isn't truly unique (fileUUID is)
# WARNING:pyabf.abf:fileGUID isn't truly unique (fileUUID is)
# WARNING:pyabf.abf:fileGUID isn't truly unique (fileUUID is)
# WARNING:pyabf.abf:fileGUID isn't truly unique (fileUUID is)
# WARNING:pyabf.abf:fileGUID isn't truly unique (fileUUID is)
# WARNING:pyabf.abf:fileGUID isn't truly unique (fileUUID is)
# WARNING:pyabf.abf:fileGUID isn't truly unique (fileUUID is)
# WARNING:pyabf.abf:fileGUID isn't truly unique (fileUUID is)
# WARNING:pyabf.abf:fileGUID isn't truly unique (fileUUID is)
# WARNING:pyabf.abf:fileGUID isn't truly unique (fileUUID is)
# ...
